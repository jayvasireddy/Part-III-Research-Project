# %% [markdown]
# ## DEFINING FUNCTIONS

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import torch
from torch import eye, ones
from sbi.utils import BoxUniform
from torch.distributions import LogNormal, Independent
from torch.distributions import MultivariateNormal
from joblib import Parallel, delayed
from sbi.analysis import pairplot, marginal_plot
from sbi.inference import NPE
from sbi.analysis import plot_summary

_ = torch.manual_seed(42)

_ = np.random.seed(0)


# Define likelihood function, ~N(\theta+loc, diag(scale)) in num_dims dimensions
def simulator(theta, loc, scale):
    """linear gaussian inspired by sbibm
    https://github.com/sbi-benchmark/sbibm/blob/15f068a08a938383116ffd92b92de50c580810a3/sbibm/tasks/gaussian_linear/task.py#L74
    """
    num_dim = theta.shape[-1]
    cov_ = scale * eye(num_dim)  # always positively semi-definite

    # using validate_args=False disables sanity checks on `covariance_matrix`
    # for the sake of speed
    value = MultivariateNormal(
        loc=(theta + loc), covariance_matrix=cov_, validate_args=False
    ).sample()
    return value


def noisy_correlated_simulator(theta, loc, scale, eps):
    num_dim = theta.shape[-1]
    device, dtype = theta.device, theta.dtype

    cov_ = scale * torch.eye(num_dim, device=device, dtype=dtype)

    # add small constant off-diagonal covariance
    off = eps * scale * (torch.ones((num_dim, num_dim), device=device, dtype=dtype) - torch.eye(num_dim, device=device, dtype=dtype))
    cov_ = cov_ + off

    value = MultivariateNormal(loc=(theta + loc), covariance_matrix=cov_, validate_args=False).sample()
    return value

# Wrapper Function to choose prior distn
def choose_prior_and_generate_theta(num_dim, num_simulations):
    prior_mean = ones(num_dim)      #mean vector [1,1]
    prior_cov = 2 * eye(num_dim)       # cov of 2* identity matrix
    prior = MultivariateNormal(
    loc=prior_mean, covariance_matrix=prior_cov, validate_args=False
    )
    
    theta = prior.sample((num_simulations,))
    return prior, theta

# plot to check simulated data covers observed data
def plot_checker(x, x_obs):
        if getattr(x_obs, "ndim", None) == 2 and x_obs.shape[0] == 1:
            x_obs = x_obs[0]    
        _ = pairplot(
        samples=x,
        points=x_obs[None, :],  # `points` needs a batch dimension.
        figsize=(4, 4),
    )

# cd /mnt/c/Users/vasir/Documents/0\ Research\ Project

# %%
# Generate net, stopping after max epochs, choosing or not choosing to 
def train_net_generate_samples(x,theta,x_obs, prior, verbose, max_epoch,true_val, loc, scale):
    
    inference = NPE(prior= prior, density_estimator="nsf")
    posterior_net = inference.append_simulations(theta, x).train(training_batch_size=200,max_num_epochs=max_epoch, stop_after_epochs=30)
    posterior_direct = inference.build_posterior(density_estimator=posterior_net,sample_with="direct")
    posterior_mcmc = inference.build_posterior(density_estimator=posterior_net,sample_with="mcmc")
    samples = posterior_direct.sample((10_000,), x=x_obs)
    predictive_samples = simulator(samples,loc,scale)

    if verbose == True:
        _ = plot_summary(
        inference,
        tags=["training_loss", "validation_loss"],
        figsize=(10, 2),
        )

        print(posterior_mcmc)
        print("Observation: ", x_obs)

        _ = pairplot(
            samples=samples,
            points=true_val,
            limits=list(zip(true_val.flatten() - 1.0, true_val.flatten() + 1.0, strict=False)),
            upper="kde",
            diag="kde",
            figsize=(5, 5),
            labels=[rf"$\theta_{d}$" for d in range(samples.shape[1])],
            )

        _ = pairplot(
            samples=predictive_samples,
            points=x_obs,
            limits=list(zip(x_obs.flatten() - 1.0, x_obs.flatten() + 1.0, strict=False)),
            upper="kde",
            diag="kde",
            figsize=(5, 5),
            labels=[rf"$x_{d}$" for d in range(3)], # this range is probbaly not future proof
            )
   
    return samples, posterior_mcmc, posterior_direct, inference

# %% [markdown]
# ## MODEL TRAINING

# %%
num_dim = 2 # 2d gaussian
num_simulations = 25_000    # no of training pairs we generate
max_epoch = 150

# these are our noise parameters
loc1 = 0.05 
scale1 = 0.03

loc2 = loc1 #-0.02
scale2 = scale1 # 0.1

# eps controls the off-diagonal correlation injected into the OBSERVED data
# only. Per James (2026-04-22), the systematic must NOT appear in training
# data; it manifests at test time through the observed split x_obs2.
eps = 0.5


prior, theta=choose_prior_and_generate_theta(num_dim, num_simulations)

# Both training splits use the null simulator: this is the corrected setup
# where posterior1 and posterior2 are both trained on data with no
# systematic. The observed splits below break that symmetry to mimic an
# observation contaminated by an unknown correlation systematic.
x1 = simulator(theta, loc1, scale1) # null training draws
x2 = simulator(theta, loc2, scale2) # null training draws (was noisy_correlated_simulator -- removed per James)

theta_observed = prior.sample((1,))
x_obs1 = simulator(theta_observed, loc1, scale1)                       # null observation
x_obs2 = noisy_correlated_simulator(theta_observed, loc2, scale2, eps) # observation with systematic injected

# %%
# Prior checks: does observation fall in prior support
plot_checker(x1,x_obs1)
plot_checker(x2,x_obs2)

# %%
samples1, posterior1_mcmc, posterior1_direct, inference1 = train_net_generate_samples(x1,theta,x_obs1, prior, verbose = True, max_epoch=max_epoch, true_val=theta_observed, loc=loc1, scale=scale1)
# Out:
#  Training neural network. Epochs trained: 137
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 samples1, posterior1_mcmc, posterior1_direct, inference1 = train_net_generate_samples(x1,theta,x_obs1, prior, verbose = True, max_epoch=max_epoch, true_val=theta_observed, loc=loc1, scale=scale1)
#
# Cell In[2], line 5, in train_net_generate_samples(x, theta, x_obs, prior, verbose, max_epoch, true_val, loc, scale)
#       2 def train_net_generate_samples(x,theta,x_obs, prior, verbose, max_epoch,true_val, loc, scale):
#       4     inference = NPE(prior= prior, density_estimator="nsf")
# ----> 5     posterior_net = inference.append_simulations(theta, x).train(training_batch_size=200,max_num_epochs=max_epoch, stop_after_epochs=30)
#       6     posterior_direct = inference.build_posterior(density_estimator=posterior_net,sample_with="direct")
# ...

# %%
samples2, posterior2_mcmc, posterior2_direct, inference2 = train_net_generate_samples(x2,theta,x_obs2, prior, verbose = True, max_epoch=max_epoch, true_val=theta_observed, loc=loc2, scale=scale2)
# Out:
#  Neural network successfully converged after 106 epochs.
#   0%|          | 0/10000 [00:00<?, ?it/s]
# For an interactive, detailed view of the summary, launch tensorboard  with 'tensorboard --logdir=c:\Users\vasir\Documents\0 Research Project\2D Gaussian Example\sbi-logs\NPE_C\2026-02-17T13_18_47.275332' from a terminal on your machine, visit http://127.0.0.1:6006 afterwards. Requires port forwarding if tensorboard runs on a remote machine, as e.g. https://stackoverflow.com/a/42445070/7770835 explains.
#
# Valid tags are: ['best_validation_loss', 'epoch_durations_sec', 'epochs_trained', 'training_loss', 'validation_loss'].
# Posterior p(θ|x) of type MCMCPosterior. It provides MCMC to .sample() from the posterior and can evaluate the _unnormalized_ posterior density with .log_prob().
# Observation:  tensor([[2.8390, 0.0925]])

# %% [markdown]
# ## POSTERIOR CHECKS/SBC - Needs adapting still

# %%
'''
posterior_samples = posterior1_mcmc.sample((10,), x=x_obs)
posterior_predictives = parallel_simulate(posterior_samples)

posterior_predictive_summary_stats = torch.as_tensor(
    np.asarray([summarize_simulation(sim) for sim in simulation_outputs]),
    dtype=torch.float32
)
fig, ax = plt.subplots(1, 1, figsize=(6, 3))
_ = ax.plot(time_vec, observation[:, 0], c="b")
_ = ax.plot(time_vec, observation[:, 1], c="orange")
for i in range(10):
    _ = ax.plot(time_vec, posterior_predictives[i, :, 0], c="b", alpha=0.2)
    _ = ax.plot(time_vec, posterior_predictives[i, :, 1], c="orange", alpha=0.2)
_ = ax.legend(["Prey", "Predator"])
_ = ax.set_xlabel("Time")
_ = ax.set_ylabel("Population")

num_sbc_samples = 200  # choose a number of sbc runs, should be ~100s

prior_samples = prior.sample((num_sbc_samples,))

prior_predictives = parallel_simulate(prior_samples)
prior_predictive_summary_stats = torch.as_tensor(
    np.asarray([summarize_simulation(sim) for sim in prior_predictives]),
    dtype=torch.float32
)

from sbi.diagnostics import run_sbc

# run SBC: for each inference we draw 1000 posterior samples.
num_posterior_samples = 1_000
ranks, dap_samples = run_sbc(
    prior_samples,
    prior_predictive_summary_stats,
    posterior,
    reduce_fns=lambda theta, x: -posterior.log_prob(theta, x),
    num_posterior_samples=num_posterior_samples,
    use_batched_sampling=False,  # `True` can give speed-ups, but can cause memory issues.
)

from sbi.analysis.plot import sbc_rank_plot

fig, ax = sbc_rank_plot(
    ranks,
    num_posterior_samples,
    plot_type="cdf",
    num_bins=20,
    figsize=(5, 3),
)


'''
# Out:
# '\nposterior_samples = posterior1_mcmc.sample((10,), x=x_obs)\nposterior_predictives = parallel_simulate(posterior_samples)\n\nposterior_predictive_summary_stats = torch.as_tensor(\n    np.asarray([summarize_simulation(sim) for sim in simulation_outputs]),\n    dtype=torch.float32\n)\nfig, ax = plt.subplots(1, 1, figsize=(6, 3))\n_ = ax.plot(time_vec, observation[:, 0], c="b")\n_ = ax.plot(time_vec, observation[:, 1], c="orange")\nfor i in range(10):\n    _ = ax.plot(time_vec, posterior_predictives[i, :, 0], c="b", alpha=0.2)\n    _ = ax.plot(time_vec, posterior_predictives[i, :, 1], c="orange", alpha=0.2)\n_ = ax.legend(["Prey", "Predator"])\n_ = ax.set_xlabel("Time")\n_ = ax.set_ylabel("Population")\n\nnum_sbc_samples = 200  # choose a number of sbc runs, should be ~100s\n\nprior_samples = prior.sample((num_sbc_samples,))\n\nprior_predictives = parallel_simulate(prior_samples)\nprior_predictive_summary_stats = torch.as_tensor(\n    np.asarray([summarize_simulation(sim) for sim in p
# ...

# %% [markdown]
# ## SAVING RESULTS

# %%
results = {
        "samples1": samples1,          # posterior samples (1000, 2)
        "samples2": samples2,          # posterior samples (1000, 2)
        "posterior1_mcmc": posterior1_mcmc,   # sbi posterior object (if you want to reuse it)
        "posterior1_direct": posterior1_direct,   # sbi posterior object (if you want to reuse it)
        "posterior2_mcmc": posterior2_mcmc,   # sbi posterior object (if you want to reuse it)
        "posterior2_direct": posterior2_direct,   # sbi posterior object (if you want to reuse it)
        "inference1": inference1,      # NPE object
        "inference2": inference2,      # NPE object
        "prior": prior,
        "theta": theta,              # simulated Î¸ used for training (10000, 4)
        "x1": x1,
        "x2": x2,                                   # 
        "x_obs1": x_obs1,              # 
        "x_obs2": x_obs2,
        "loc1": loc1,
        "loc2" : loc2,
        "scale1": scale1, 
        "scale2": scale2,
        "theta_observed": theta_observed,
        "eps": eps                      
    }


fname = f"off_diag_CALIBRATION TESTER_gaussian_loc1_{eps}.pt"
torch.save(results, fname)
# Out:
# c:\Users\vasir\Documents\0 Research Project\.venv\Lib\site-packages\torch\serialization.py:1088: UserWarning: When the inference object is pickled, the behaviour of the loaded object changes in the following two ways: 1) `.train(..., retrain_from_scratch=True)` is not supported. 2) When the loaded object calls the `.train()` method, it generates a new tensorboard summary writer (instead of appending to the current one).
#   pickler.dump(obj)

# %% [markdown]
# ## KL CALIBRATION CODE

# %% [markdown]
# #### Loading Results and Plots to check

# %%
def load_results_file(file_name):
    res = torch.load(file_name)
    return res

def extract_results(res):
    """
    Given a loaded results dict, return a tuple in a fixed order.
    This is explicit and avoids surprises.
    """
    keys = [
        "samples1", "samples2",
        "posterior1_mcmc", "posterior1_direct",
        "posterior2_mcmc", "posterior2_direct",
        "inference1", "inference2",
        "prior",
        "theta",
        "x1", "x2",
        "x_obs1", "x_obs2",
        "loc1","loc2", 
        "scale1","scale2", "theta_observed",
        "eps"
        
    ]

    

    missing = [k for k in keys if k not in res]
    if missing:
        raise KeyError(f"Missing keys in results dict: {missing}")

    return tuple(res[k] for k in keys)

# %%
fname1 = "off_diag_CALIBRATION TESTER_gaussian_loc1.pt"
fname2 = "off_diag_CALIBRATION TESTER_gaussian_loc1_0.5.pt"


res = load_results_file(fname2)
# update to include t_span when we retrain models
# update to include true_params if needed but think first
(samples1, samples2,
 posterior1_mcmc, posterior1_direct,
 posterior2_mcmc, posterior2_direct,
 inference1, inference2,
 prior,
 theta,
 x1, x2,
 x_obs1, x_obs2,
 loc1, loc2, scale1, scale2, theta_observed, eps
) = extract_results(res)
# Out:
# /tmp/ipykernel_395025/293419691.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   res = torch.load(file_name)

# %%
### ADJUSTEMENTS
def noisy_scaled_cov_simulator(theta, loc, scale, delta):
    num_dim = theta.shape[-1]
    device, dtype = theta.device, theta.dtype

    # base covariance
    cov_ = scale * torch.eye(num_dim, device=device, dtype=dtype)

    # apply variance miscalibration (scale the covariance)
    cov_ = (1 + delta) * cov_

    value = MultivariateNormal(
        loc=(theta + loc),
        covariance_matrix=cov_,
        validate_args=False
    ).sample()

    return value

delta_investigate= 0.5

x_obs2_new = noisy_scaled_cov_simulator(theta_observed, loc1, scale1, delta_investigate)
samples2_new = posterior2_direct.sample((10_000,), x=x_obs2_new)
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]
# /data/vault/jv447/venvs/research-project/lib/python3.11/site-packages/nflows/transforms/lu.py:80: UserWarning: torch.triangular_solve is deprecated in favor of torch.linalg.solve_triangularand will be removed in a future PyTorch release.
# torch.linalg.solve_triangular has its arguments reversed and does not return a copy of one of the inputs.
# X = torch.triangular_solve(B, A).solution
# should be replaced with
# X = torch.linalg.solve_triangular(A, B). (Triggered internally at ../aten/src/ATen/native/BatchLinearAlgebra.cpp:2190.)
#   outputs, _ = torch.triangular_solve(

# %% [markdown]
# #### Need adjusting for off-diag

# %%
# Define analytical solutions for the null model.
#
# Both posterior1 and posterior2 are trained on the null simulator
# (no off-diagonal correlation), so the analytic that the trained networks
# should match is the *null* posterior conditional on each observation --
# even when the observation itself contains the systematic (x_obs2). This
# is the failure mode James/Will discussed: the network converges
# correctly to the null posterior, NPC-style diagnostics pass, yet the
# inferred posterior is biased relative to the true generating process.

def posterior_params(x_obs, loc, scale):
    """Conjugate Gaussian posterior under the null (diagonal) likelihood.
    Prior:        theta ~ N([1,1], 2*I)
    Likelihood:   x | theta ~ N(theta + loc, scale * I)
    """
    x_obs = torch.as_tensor(x_obs)
    loc   = torch.as_tensor(loc, dtype=x_obs.dtype, device=x_obs.device)
    s     = torch.as_tensor(scale, dtype=x_obs.dtype, device=x_obs.device)  # variance

    mu_post = (s * torch.ones_like(x_obs) + 2 * (x_obs - loc)) / (s + 2)
    Sigma_post = (2 * s / (s + 2)) * torch.eye(x_obs.numel(), dtype=x_obs.dtype, device=x_obs.device)
    return mu_post, Sigma_post


def posterior_params_correlated(x_obs, loc, scale, eps, prior=None):
    """
    NOTE (kept for reference / motivation plots only -- NOT the analytic
    that the trained NPE should match under the corrected methodology).

    True data-generating posterior when the *likelihood itself* has
    off-diagonal correlation. Useful for visualising the bias between
    what the null-trained NPE converges to and the truth.
    """
    x_obs = torch.as_tensor(x_obs)
    loc   = torch.as_tensor(loc, dtype=x_obs.dtype, device=x_obs.device)
    s     = torch.as_tensor(scale, dtype=x_obs.dtype, device=x_obs.device)
    rho   = torch.as_tensor(eps,   dtype=x_obs.dtype, device=x_obs.device)

    if x_obs.numel() != 2:
        raise ValueError(f"Expected 2D observation, got shape {tuple(x_obs.shape)}")
    if not torch.all(torch.abs(rho) < 1):
        raise ValueError(f"Need |eps| < 1 since eps is correlation. Got eps={rho.item()}")

    if prior is None:
        mu0 = torch.ones(2, dtype=x_obs.dtype, device=x_obs.device)
        Sigma0 = 2.0 * torch.eye(2, dtype=x_obs.dtype, device=x_obs.device)
    else:
        mu0 = prior.loc.to(dtype=x_obs.dtype, device=x_obs.device)
        Sigma0 = prior.covariance_matrix.to(dtype=x_obs.dtype, device=x_obs.device)

    SigmaL = s * torch.tensor([[1.0, rho], [rho, 1.0]], dtype=x_obs.dtype, device=x_obs.device)

    I = torch.eye(2, dtype=x_obs.dtype, device=x_obs.device)
    Sigma0_inv = torch.linalg.solve(Sigma0, I)
    SigmaL_inv = torch.linalg.solve(SigmaL, I)
    Sigma_post = torch.linalg.solve(Sigma0_inv + SigmaL_inv, I)

    d = x_obs.reshape(2) - loc
    eta = Sigma0_inv @ mu0 + SigmaL_inv @ d
    mu_post = Sigma_post @ eta

    return mu_post, Sigma_post


# Both analytic targets now use the null posterior_params -- this is the
# correct check for whether each trained network converged on the null
# posterior it was trained for.
mu_post1, Sigma_post1 = posterior_params(x_obs1, loc1, scale1)
mu_post2, Sigma_post2 = posterior_params(x_obs2_new, loc2, scale2)

# %%
# Plot posteriors vs analytic solutions to check training: 


analytic_samples1 = MultivariateNormal(mu_post1, Sigma_post1, validate_args=False).sample((20_000,)).reshape(-1, 2)
analytic_samples2 = MultivariateNormal(mu_post2, Sigma_post2, validate_args=False).sample((20_000,)).reshape(-1, 2)

fig1, ax1 = marginal_plot(
    samples=[samples1, analytic_samples1],
    diag=["kde", "kde"],
    labels=[r"$\theta_0$", r"$\theta_1$"],
    figsize=(6, 2),
)
fig1.suptitle("SBI vs analytic marginals, split 1", y=1.05)

fig2, ax2 = marginal_plot(
    samples=[samples2_new, analytic_samples2],
    diag=["kde", "kde"],
    labels=[r"$\theta_0$", r"$\theta_1$"],
    figsize=(6, 2),
)
fig2.suptitle("SBI vs analytic marginals, split 2", y=1.05)
# Out:
# Text(0.5, 1.05, 'SBI vs analytic marginals, split 2')

# %%
### Note this cell is gpt generated playing around with codex in vs code


# Overlay analytical Gaussian posterior on top of SBI posterior samples (2D only)
def analytic_posterior_gaussian(
    prior_mean,
    prior_cov,
    x_obs,
    loc,
    scale,
    eps=None,
    likelihood_cov=None,
):
    """
    Closed-form posterior for:
      prior:  theta ~ N(mu0, Sigma0)
      likelihood: x | theta ~ N(theta + loc, Sigma_lik)

    Sigma_lik is built as:
      - isotropic: scale * I
      - with constant off-diagonal correlation: scale * I + eps * (1 - I)
      - or directly supplied as `likelihood_cov` (full covariance matrix)
    """
    mu0 = prior_mean.reshape(-1, 1)
    Sigma0 = prior_cov
    num_dim = Sigma0.shape[-1]

    dtype = Sigma0.dtype
    device = Sigma0.device
    eye = torch.eye(num_dim, dtype=dtype, device=device)

    if likelihood_cov is not None:
        Sigma_lik = torch.as_tensor(likelihood_cov, dtype=dtype, device=device)
        if Sigma_lik.ndim == 0:
            Sigma_lik = Sigma_lik * eye
        elif Sigma_lik.ndim == 1:
            Sigma_lik = torch.diag(Sigma_lik)
    else:
        scale_t = torch.as_tensor(scale, dtype=dtype, device=device)
        if scale_t.ndim == 0:
            Sigma_lik = scale_t * eye
        elif scale_t.ndim == 1:
            Sigma_lik = torch.diag(scale_t)
        else:
            Sigma_lik = scale_t

        if eps is not None:
            eps_t = torch.as_tensor(eps, dtype=dtype, device=device)
            Sigma_lik = Sigma_lik + eps_t * (torch.ones((num_dim, num_dim), dtype=dtype, device=device) - eye)

    loc_t = torch.as_tensor(loc, dtype=dtype, device=device)
    loc_center = loc_t if loc_t.ndim == 0 else loc_t.reshape(-1, 1)

    Sigma0_inv = torch.linalg.inv(Sigma0)
    Sigma_lik_inv = torch.linalg.inv(Sigma_lik)

    x_centered = x_obs.reshape(-1, 1).to(dtype=dtype, device=device) - loc_center
    Sigma_post = torch.linalg.inv(Sigma0_inv + Sigma_lik_inv)
    mu_post = Sigma_post @ (Sigma0_inv @ mu0 + Sigma_lik_inv @ x_centered)
    return mu_post.flatten(), Sigma_post


def plot_posterior_with_gaussian_overlay(
    samples,
    x_obs,
    loc,
    scale,
    prior,
    theta_true,
    title,
    eps=None,
    likelihood_cov=None,
):
    if samples.shape[1] != 2:
        raise ValueError("This overlay plot is only implemented for 2D.")

    prior_mean = prior.loc
    prior_cov = prior.covariance_matrix
    mu_post, Sigma_post = analytic_posterior_gaussian(
        prior_mean,
        prior_cov,
        x_obs,
        loc,
        scale,
        eps=eps,
        likelihood_cov=likelihood_cov,
    )

    # Build grid around posterior mean
    mu_np = mu_post.detach().cpu().numpy()
    Sigma_np = Sigma_post.detach().cpu().numpy()
    stds = np.sqrt(np.diag(Sigma_np))
    grid_min = mu_np - 4 * stds
    grid_max = mu_np + 4 * stds

    gx = np.linspace(grid_min[0], grid_max[0], 200)
    gy = np.linspace(grid_min[1], grid_max[1], 200)
    XX, YY = np.meshgrid(gx, gy)
    grid = np.stack([XX, YY], axis=-1)

    mvn = MultivariateNormal(mu_post, Sigma_post, validate_args=False)
    grid_t = torch.from_numpy(grid).float().reshape(-1, 2)
    ZZ = torch.exp(mvn.log_prob(grid_t)).reshape(200, 200).detach().cpu().numpy()

    samples_np = samples.detach().cpu().numpy()
    theta_true_np = theta_true.detach().cpu().numpy().reshape(-1)

    plt.figure(figsize=(5, 5))
    plt.scatter(samples_np[:, 0], samples_np[:, 1], s=6, alpha=0.25, label="SBI posterior samples")
    plt.contour(XX, YY, ZZ, levels=6, colors="black", linewidths=1.0, alpha=0.8, label="Analytic posterior")
    plt.scatter(theta_true_np[0], theta_true_np[1], c="red", s=40, label="True theta")
    plt.title(title)
    plt.xlabel(r"$\theta_0$")
    plt.ylabel(r"$\theta_1$")
    plt.legend()
    plt.tight_layout()


# Example overlays for the two observation settings
plot_posterior_with_gaussian_overlay(
    samples1, x_obs1, loc1, scale1, prior, theta_observed,
    title="Posterior (loc1/scale1) with analytic Gaussian overlay",
)

# posterior2 is now null-trained, so overlay the *null* analytic
# (no eps) -- this is the convergence check. The bias relative to the
# true correlated-likelihood posterior is what the D_KL test detects.
plot_posterior_with_gaussian_overlay(
    samples2, x_obs2, loc2, scale2, prior, theta_observed,
    title="Posterior (loc2/scale2) with null-analytic Gaussian overlay",
)

# %% [markdown]
# #### KL Definitions

# %%
#plot posteriors overlayed

_ = pairplot(
            samples=[samples1, samples2_new],
            points=theta_observed,
            limits=list(zip(theta_observed.flatten() - 1.0, theta_observed.flatten() + 1.0, strict=False)),
            upper="kde",
            diag="kde",
            figsize=(5, 5),
            labels=[rf"$\theta_{d}$" for d in range(samples1.shape[1])],
            )

# %% [markdown]
# #### Better pairplots (Will's Apr-9 / Apr-14 asks)
#
# Three diagnostic views in both `sbi.pairplot` and `getdist` flavours.

# %%
# ============================================================
# Presentation-quality pairplots — sbi.pairplot version
# (Will's April-9 / April-14 asks)
#   Plot 1 — prior vs both NPE posteriors
#   Plot 2 — analytic null posterior vs both NPE posteriors
#            (training validation: each NPE should match the analytic
#             null posterior conditioned on its own observation)
#   Plot 3 — null vs systematic NPE posteriors (the actual test)
# ============================================================

import matplotlib as mpl
import matplotlib.patches as mpatches
from torch.distributions import MultivariateNormal as _MVN

_RC = {
    "font.size":       16,
    "axes.labelsize":  18,
    "xtick.labelsize": 13,
    "ytick.labelsize": 13,
    "axes.titlesize":  16,
}

G2D_PARAM_LABELS = [r"$\theta_0$", r"$\theta_1$"]


def _style_axes(axes):
    for row in axes:
        for ax in row:
            if ax is None:
                continue
            ax.tick_params(axis="both", labelsize=13, length=4, width=0.8)
            ax.xaxis.label.set_size(17)
            ax.yaxis.label.set_size(17)
            for spine in ax.spines.values():
                spine.set_linewidth(0.8)


def _add_legend(fig, entries):
    handles = [mpatches.Patch(facecolor=c, edgecolor="0.3", linewidth=0.8, label=lbl)
               for c, lbl in entries]
    leg = fig.legend(
        handles=handles, fontsize=15, frameon=True,
        facecolor="white", edgecolor="0.3",
        loc="lower left", bbox_to_anchor=(0.02, 0.02),
        borderpad=0.9, handlelength=1.5, handleheight=1.2,
    )
    leg.get_frame().set_linewidth(1.0)


def _to_tensor2(s):
    if not torch.is_tensor(s):
        s = torch.tensor(np.asarray(s, dtype=np.float32))
    return s.clone().float().reshape(-1, 2)


def _empirical_limits2(samples_list, pad_frac=0.05):
    arr = np.concatenate([s.numpy() if torch.is_tensor(s) else np.asarray(s, dtype=float)
                          for s in samples_list], axis=0)
    mn, mx = arr.min(axis=0), arr.max(axis=0)
    pad    = pad_frac * (mx - mn)
    return [[mn[i] - pad[i], mx[i] + pad[i]] for i in range(2)]


def _draw_analytic_null(x_obs, loc, scale, n=20_000):
    """Draw samples from the analytic null Gaussian posterior."""
    mu, Sigma = posterior_params(x_obs, loc, scale)
    return _MVN(mu, Sigma, validate_args=False).sample((n,)).reshape(-1, 2)


def _true_point(theta_observed):
    t = theta_observed
    if torch.is_tensor(t):
        t = t.detach().cpu().numpy()
    return np.asarray(t, dtype=float).reshape(-1)[:2]


def plot_prior_vs_posteriors_g2d(samples1, samples2, prior, theta_observed,
                                  n_prior_samples=30_000):
    prior_samples = prior.sample((n_prior_samples,))
    prior_plot    = _to_tensor2(prior_samples)
    post1_plot    = _to_tensor2(samples1)
    post2_plot    = _to_tensor2(samples2)

    true_pt = _true_point(theta_observed)

    with mpl.rc_context(_RC):
        fig, axes = pairplot(
            samples=[prior_plot, post1_plot, post2_plot],
            points=torch.tensor(true_pt, dtype=torch.float32)[None, :],
            limits=_empirical_limits2([prior_plot]),
            figsize=(9, 9),
            labels=G2D_PARAM_LABELS,
            fig_kwargs={"points_colors": ["black"], "legend": False},
        )

    _style_axes(axes)
    _add_legend(fig, [
        ("#1f77b4", "Prior"),
        ("#2ca02c", "NPE posterior — split 1"),
        ("#9467bd", "NPE posterior — split 2"),
    ])
    fig.suptitle("Prior vs Posteriors", fontsize=22, fontweight="bold", y=1.01)
    plt.tight_layout()
    plt.show()


def plot_analytic_vs_posteriors_g2d(samples1, samples2, theta_observed,
                                     x_obs1, loc1, scale1,
                                     x_obs2, loc2, scale2):
    """Each NPE is trained on null data; under James's corrected setup
    each posterior should match the analytic null posterior conditioned
    on its own observation. This plot is the standard NPE convergence
    check (cf. methodology_discussion_notes.md)."""
    analytic1 = _draw_analytic_null(x_obs1, loc1, scale1)
    analytic2 = _draw_analytic_null(x_obs2, loc2, scale2)

    a1_plot = _to_tensor2(analytic1)
    a2_plot = _to_tensor2(analytic2)
    p1_plot = _to_tensor2(samples1)
    p2_plot = _to_tensor2(samples2)

    true_pt = _true_point(theta_observed)
    tight   = _empirical_limits2([p1_plot, p2_plot, a1_plot, a2_plot], pad_frac=0.15)

    with mpl.rc_context(_RC):
        fig, axes = pairplot(
            samples=[a1_plot, a2_plot, p1_plot, p2_plot],
            points=torch.tensor(true_pt, dtype=torch.float32)[None, :],
            limits=tight,
            figsize=(9, 9),
            labels=G2D_PARAM_LABELS,
            fig_kwargs={"points_colors": ["black"], "legend": False},
        )

    _style_axes(axes)
    _add_legend(fig, [
        ("#1f77b4", "Analytic null posterior — split 1"),
        ("#2ca02c", "Analytic null posterior — split 2"),
        ("#ff7f0e", "NPE posterior — split 1"),
        ("#9467bd", "NPE posterior — split 2"),
    ])
    fig.suptitle("Analytic Null vs NPE Posteriors", fontsize=22, fontweight="bold", y=1.01)
    plt.tight_layout()
    plt.show()


def plot_posteriors_overlaid_g2d(samples1, samples2, theta_observed):
    p1_plot = _to_tensor2(samples1)
    p2_plot = _to_tensor2(samples2)
    true_pt = _true_point(theta_observed)
    tight   = _empirical_limits2([p1_plot, p2_plot], pad_frac=0.15)

    with mpl.rc_context(_RC):
        fig, axes = pairplot(
            samples=[p1_plot, p2_plot],
            points=torch.tensor(true_pt, dtype=torch.float32)[None, :],
            limits=tight,
            figsize=(9, 9),
            labels=G2D_PARAM_LABELS,
            fig_kwargs={"points_colors": ["black"], "legend": False},
        )

    _style_axes(axes)
    _add_legend(fig, [
        ("#1f77b4", "NPE posterior — split 1 (null observation)"),
        ("#2ca02c", "NPE posterior — split 2 (potential systematic)"),
    ])
    fig.suptitle("Split 1 vs Split 2 Posteriors", fontsize=22, fontweight="bold", y=1.01)
    plt.tight_layout()
    plt.show()


# --- Run ---
plot_prior_vs_posteriors_g2d(samples1, samples2_new, prior, theta_observed)
plot_analytic_vs_posteriors_g2d(
    samples1, samples2_new, theta_observed,
    x_obs1, loc1, scale1,
    x_obs2_new, loc2, scale2,
)
plot_posteriors_overlaid_g2d(samples1, samples2_new, theta_observed)

# %%
# ============================================================
# getdist versions (Will's Apr-14 ask — peak=1 1D marginals)
# ============================================================
#%pip install --quiet getdist
from getdist import MCSamples, plots as gd_plots

G2D_GD_NAMES  = ["theta_0", "theta_1"]
G2D_GD_LABELS = [r"\theta_0", r"\theta_1"]


def _to_mcsamples_g2d(samples, label):
    arr = samples.numpy() if torch.is_tensor(samples) else np.asarray(samples)
    arr = arr.astype(float).reshape(-1, 2).copy()
    return MCSamples(samples=arr, names=G2D_GD_NAMES, labels=G2D_GD_LABELS, label=label)


def _make_plotter_g2d(width_inch=9):
    g = gd_plots.get_subplot_plotter(width_inch=width_inch)
    g.settings.norm_1d_density          = True
    g.settings.alpha_filled_add         = 0.6
    g.settings.axes_fontsize            = 13
    g.settings.lab_fontsize             = 18
    g.settings.legend_fontsize          = 14
    g.settings.linewidth                = 2.0
    g.settings.linewidth_contour        = 2.0
    g.settings.solid_contour_palefactor = 0.7
    return g


def _true_markers_g2d(theta_observed):
    t = theta_observed
    if torch.is_tensor(t):
        t = t.detach().cpu().numpy()
    t = np.asarray(t, dtype=float).reshape(-1)[:2]
    return dict(zip(G2D_GD_NAMES, t))


def plot_prior_vs_posteriors_g2d_gd(samples1, samples2, prior, theta_observed,
                                     n_prior_samples=30_000):
    mc_prior = _to_mcsamples_g2d(prior.sample((n_prior_samples,)), "Prior")
    mc1      = _to_mcsamples_g2d(samples1, "NPE posterior - split 1")
    mc2      = _to_mcsamples_g2d(samples2, "NPE posterior - split 2")

    g = _make_plotter_g2d()
    g.triangle_plot(
        [mc_prior, mc1, mc2],
        filled=True,
        contour_colors=["#888888", "#1f77b4", "#ff7f0e"],
        markers=_true_markers_g2d(theta_observed),
        legend_loc="upper right",
    )
    plt.suptitle("Prior vs Posteriors (getdist)", fontsize=22, fontweight="bold", y=1.02)
    plt.show()


def plot_analytic_vs_posteriors_g2d_gd(samples1, samples2, theta_observed,
                                        x_obs1, loc1, scale1,
                                        x_obs2, loc2, scale2):
    a1 = _draw_analytic_null(x_obs1, loc1, scale1)
    a2 = _draw_analytic_null(x_obs2, loc2, scale2)

    mc_a1 = _to_mcsamples_g2d(a1,        "Analytic null - split 1")
    mc_a2 = _to_mcsamples_g2d(a2,        "Analytic null - split 2")
    mc_p1 = _to_mcsamples_g2d(samples1,  "NPE posterior - split 1")
    mc_p2 = _to_mcsamples_g2d(samples2,  "NPE posterior - split 2")

    g = _make_plotter_g2d()
    g.triangle_plot(
        [mc_a1, mc_a2, mc_p1, mc_p2],
        filled=True,
        contour_colors=["#1f77b4", "#2ca02c", "#ff7f0e", "#9467bd"],
        markers=_true_markers_g2d(theta_observed),
        legend_loc="upper right",
    )
    plt.suptitle("Analytic Null vs NPE Posteriors (getdist)",
                 fontsize=22, fontweight="bold", y=1.02)
    plt.show()


def plot_posteriors_overlaid_g2d_gd(samples1, samples2, theta_observed):
    mc1 = _to_mcsamples_g2d(samples1, "NPE posterior - split 1")
    mc2 = _to_mcsamples_g2d(samples2, "NPE posterior - split 2")

    g = _make_plotter_g2d()
    g.triangle_plot(
        [mc1, mc2],
        filled=True,
        contour_colors=["#1f77b4", "#ff7f0e"],
        markers=_true_markers_g2d(theta_observed),
        legend_loc="upper right",
    )
    plt.suptitle("Split 1 vs Split 2 Posteriors (getdist)",
                 fontsize=22, fontweight="bold", y=1.02)
    plt.show()


# --- Run ---
plot_prior_vs_posteriors_g2d_gd(samples1, samples2_new, prior, theta_observed)
plot_analytic_vs_posteriors_g2d_gd(
    samples1, samples2_new, theta_observed,
    x_obs1, loc1, scale1,
    x_obs2_new, loc2, scale2,
)
plot_posteriors_overlaid_g2d_gd(samples1, samples2_new, theta_observed)
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# WARNING:root:fine_bins_2D not large enough for optimal density: theta_0, theta_1
# WARNING:root:fine_bins_2D not large enough for optimal density: theta_0, theta_1
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# WARNING:root:fine_bins_2D not large enough for optimal density: theta_0, theta_1
# WARNING:root:fine_bins_2D not large enough for optimal density: theta_0, theta_1
# WARNING:root:fine_bins_2D not large enough for optimal density: theta_0, theta_1
# Removed no burn in
# Removed no burn in
# WARNING:root:fine_bins_2D not large enough for optimal density: theta_0, theta_1

# %%
## Analytic KL Defintions:

# defining myself from pen and paper
def kl_gaussian_explicit(mu_p, Sigma_p, mu_q, Sigma_q):
    """
    KL( N(mu_p, Sigma_p) || N(mu_q, Sigma_q) )
    Works for d=2 (and any d), assumes Sigma_* are SPD.
    Returns a scalar tensor.
    """
    mu_p = torch.as_tensor(mu_p)
    mu_q = torch.as_tensor(mu_q)
    Sigma_p = torch.as_tensor(Sigma_p)
    Sigma_q = torch.as_tensor(Sigma_q)

    d = mu_p.numel()

    # Cholesky factors (SPD -> exists)
    Lp = torch.linalg.cholesky(Sigma_p)
    Lq = torch.linalg.cholesky(Sigma_q)

    # log |Sigma| via Cholesky: logdet = 2 * sum(log(diag(L)))
    logdet_p = 2.0 * torch.sum(torch.log(torch.diagonal(Lp)))
    logdet_q = 2.0 * torch.sum(torch.log(torch.diagonal(Lq)))

    # tr(Sigma_q^{-1} Sigma_p) using solves
    X = torch.cholesky_solve(Sigma_p, Lq)   # solves Sigma_q X = Sigma_p
    tr_term = torch.trace(X)

    # quadratic term (mu_q - mu_p)^T Sigma_q^{-1} (mu_q - mu_p)
    delta = (mu_q - mu_p).unsqueeze(-1)     # (d,1)
    v = torch.cholesky_solve(delta, Lq)     # Sigma_q^{-1} delta
    quad_term = (delta.transpose(-2, -1) @ v).squeeze()

    kl = 0.5 * ((logdet_q - logdet_p) - d + tr_term + quad_term)
    return kl

# using pytorch
def kl_gaussian_builtin(mu_p, Sigma_p, mu_q, Sigma_q):
    p = MultivariateNormal(mu_p, covariance_matrix=Sigma_p)
    q = MultivariateNormal(mu_q, covariance_matrix=Sigma_q)
    return torch.distributions.kl_divergence(p, q)


analytic_kl = kl_gaussian_explicit(mu_post1, Sigma_post1, mu_post2, Sigma_post2)
analytic_kl_pytorch = kl_gaussian_builtin(mu_post1, Sigma_post1, mu_post2, Sigma_post2)

# %%
def calc_dkl(posterior1, posterior2, x1, x2, n_theta):

    # Setting data as tensors to use with sbi lib
    x1 = torch.as_tensor(x1, dtype=torch.float32).reshape(1, -1)
    x2 = torch.as_tensor(x2, dtype=torch.float32).reshape(1, -1)

    with torch.no_grad():  # included this line to help with speed
        # take n_theta samples from posterior1 conditioned on x1
        theta_samples = posterior1.sample((n_theta,), x=x1, show_progress_bars=False)

        # access log probabilities under both posteriors
        log_post1 = posterior1.log_prob(theta_samples, x=x1, norm_posterior=True)
        log_post2 = posterior2.log_prob(theta_samples, x=x2, norm_posterior=True)

        # Monte Carlo estimate of D_KL( p1(.|x1) || p2(.|x2) )
        z = log_post1 - log_post2
        mean = z.mean().item()
        std_dev = z.std(unbiased=True).item()
        error = std_dev / np.sqrt(n_theta)

        return mean, std_dev, error


def calibrate_null_dkl(posterior1, posterior2, prior, N, n_theta,
                       loc1, scale1, loc2, scale2):
    """Null calibration of D_KL.

    Per James (2026-04-22), both posteriors are trained on null
    simulators, and the calibration MC also draws from null simulators
    -- so this function takes both trained posteriors as inputs and
    evaluates each on its respective simulated split.
    """
    dkls = np.zeros(N)
    for i in range(N):
        if i % 200 == 0:
            print(f"{i}/{N}")

        # both splits drawn from the null joint p(x, theta)
        theta_i = prior.sample((1,)).squeeze(0)
        x1_i = simulator(theta_i, loc1, scale1)
        x2_i = simulator(theta_i, loc2, scale2)

        # evaluate p1 on its split, p2 on its split (null posteriors,
        # null data -- this is the calibrated null distribution)
        dkls[i], std_dev, error = calc_dkl(posterior1, posterior2,
                                           x1_i, x2_i, n_theta=n_theta)

    crit_val_95 = float(np.quantile(dkls, 0.95))

    plt.figure(figsize=(6, 3))
    plt.hist(dkls, bins=30, density=True)
    plt.xlabel("D_KL")
    plt.ylabel("density")
    plt.title("Null calibration of D_KL (data realisations under null)")
    plt.show()

    print("Null 95 percent critical value:", crit_val_95)

    return dkls, crit_val_95

# %%
dkl_obs, std_obs, error_obs = calc_dkl(posterior1_direct, posterior2_direct,
                                       x_obs1, x_obs2_new, n_theta=10000)

print("DKL observed:", dkl_obs)
print(f"analytic_kl={analytic_kl}")
print(f"analytic_kl_pytorch={analytic_kl_pytorch}")
# Out:
# DKL observed: 0.5687512755393982
# analytic_kl=0.6710278987884521
# analytic_kl_pytorch=tensor([0.6710])

# %%
dkls, crit_val_95 = calibrate_null_dkl(posterior1_direct, posterior2_direct,
                                       prior, 1000, 2000,
                                       loc1, scale1, loc2, scale2)

# %% [markdown]
# #### Presentation-quality null calibration plot

# %%
# ============================================================
# Presentation-quality null-calibration histogram
# (matches the styling used in the CMB beam notebooks)
# ============================================================
def calibrate_null_dkl_neat(posterior1, posterior2, prior, N, n_theta,
                             loc1, scale1, loc2, scale2, dkl_obs):
    dkls = np.zeros(N)
    for i in range(N):
        if i % 200 == 0:
            print(f"{i}/{N}")
        theta_i = prior.sample((1,)).squeeze(0)
        x1_i = simulator(theta_i, loc1, scale1)
        x2_i = simulator(theta_i, loc2, scale2)
        dkls[i], _, _ = calc_dkl(posterior1, posterior2, x1_i, x2_i, n_theta=n_theta)

    crit_val_95 = float(np.quantile(dkls, 0.95))

    plt.figure(figsize=(8, 4.5), dpi=150)
    plt.gca().set_axisbelow(True)
    plt.grid(axis="y", linestyle="--", alpha=0.7)
    plt.grid(axis="x", linestyle=":",  alpha=0.4)

    plt.hist(dkls, bins=30, density=True, color="tab:blue",
             label=r"Null Distribution ($H_0$)")
    plt.axvline(dkl_obs, color="black", linestyle="dashed", linewidth=2.5,
                label=fr"Observed $D_{{KL}}$ ({dkl_obs:.2f})")
    plt.axvline(crit_val_95, color="red", linestyle="dashed", linewidth=2.5,
                label=fr"95% Critical Value ({crit_val_95:.2f})")

    plt.xlabel(r"Kullback-Leibler Divergence ($D_{KL}$)", fontsize=14, labelpad=10)
    plt.ylabel("Probability Density", fontsize=14, labelpad=10)
    plt.title(r"Null Calibration of $D_{KL}$ (2D Gaussian)", fontsize=16, pad=15)
    plt.xticks(fontsize=12); plt.yticks(fontsize=12)
    plt.legend(fontsize=12, frameon=True, shadow=True,
               facecolor="white", edgecolor="black", borderpad=0.8)
    plt.tight_layout()
    plt.show()

    print(f"Null 95 percent critical value: {crit_val_95:.2f}")
    return dkls, crit_val_95


dkls_neat, crit_val_95_neat = calibrate_null_dkl_neat(
    posterior1_direct, posterior2_direct, prior,
    1500, 500, loc1, scale1, loc2, scale2, dkl_obs,
)

# %%
#loop through N vals to see error as fn of n
N_theta_vals = [100,500,1000,5000,10000]

# empty array to store values
mean_vals=[0]*len(N_theta_vals)
std_dev_vals = [0]*len(N_theta_vals)
error_vals = [0]*len(N_theta_vals)

# generate some random test data, following same process:
def generate_loop_data(prior,loc1, scale1, loc2, scale2):
        theta_i = prior.sample((1,)).squeeze(0)
        x1_i = simulator(theta_i, loc1, scale1) 
        x2_i = simulator(theta_i, loc2, scale2) #obtaining summary statistics of data
        return x1_i, x2_i

x1_loop, x2_loop = generate_loop_data(prior, loc1, scale1, loc2, scale2)

for i in range(len(N_theta_vals)):
        n_theta = N_theta_vals[i]
        mean_vals[i], std_dev_vals[i], error_vals[i] = calc_dkl(posterior1_direct, posterior1_direct, x1_loop, x2_loop, n_theta = n_theta)
        print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
N_theta_vals = np.array(N_theta_vals, dtype=float)
mean_vals = np.array(mean_vals, dtype=float)
std_dev_vals = np.array(std_dev_vals, dtype=float)
error_vals = np.array(error_vals, dtype=float)

# Plot mean
plt.figure(figsize=(7, 4))
plt.xscale("log")
plt.plot(N_theta_vals, mean_vals, marker="o")
plt.xlabel("n_theta")
plt.ylabel("Mean (KL estimate)")
plt.title("Mean vs n_theta")
plt.tight_layout()
plt.show()

# 2) Std dev vs N_theta
plt.figure(figsize=(7, 4))
plt.xscale("log")
plt.plot(N_theta_vals, std_dev_vals, marker="o")
plt.xlabel("n_theta")
plt.ylabel("Std dev of kl")
plt.title("Std dev vs n_theta")
plt.tight_layout()
plt.show()

# 3) Error vs N_theta
plt.figure(figsize=(7, 4))
plt.xscale("log")
plt.plot(N_theta_vals, error_vals, marker="o")
plt.xlabel("n_theta")
plt.ylabel("MC error (std_dev/sqrt(n_theta))")
plt.title("MC error vs n_theta")
plt.tight_layout()
plt.show()

# %%
from scipy.stats import chi2


def calibrate_null_dkl_and_perturbed(posterior1, posterior2, prior, N, n_theta,
                                     loc1, scale1, loc2, scale2, delta):
    """Null + perturbed calibration of D_KL.

    Null branch: both posteriors evaluated on null-simulated splits.
    Perturbed branch: split 2 carries an injected off-diagonal
    correlation (mirroring x_obs2). Both posteriors remain null-trained
    -- the systematic only enters the *observed* split, per James.
    """
    dkls = np.zeros(N)
    dkls_perturbed = np.zeros(N)
    for i in range(N):
        if i % 100 == 0:
            print(f"{i}/{N}")

        # shared theta, independent null draws for the null branch
        theta_i = prior.sample((1,)).squeeze(0)
        x1_i = simulator(theta_i, loc1, scale1)
        x2_i = simulator(theta_i, loc2, scale2)

        # perturbation lives in split 2 (matches x_obs2 in the observed
        # pipeline). Posteriors are unchanged -- still null-trained.
        x2_i_perturbed = noisy_scaled_cov_simulator(theta_i, loc2, scale2, delta)

        dkls[i], std_dev, error = calc_dkl(posterior1, posterior2,
                                           x1_i, x2_i, n_theta=n_theta)
        dkls_perturbed[i], std_dev2, error2 = calc_dkl(posterior1, posterior2,
                                                       x1_i, x2_i_perturbed,
                                                       n_theta=n_theta)

    crit_val_95 = float(np.quantile(dkls, 0.95))
    crit_val_95_perturbed = float(np.quantile(dkls_perturbed, 0.95))

    # analytic null D_KL distribution (scaled chi^2_2) for a sanity overlay
    s = float(scale1)
    c = 2.0 / (s + 2.0)
    x_max = max(np.max(dkls), 15.0)
    x_vals = np.linspace(0.01, x_max, 200)
    pdf_theoretical = (1.0 / c) * chi2.pdf(x_vals / c, df=2)

    plt.figure(figsize=(6, 3))
    plt.hist(dkls, bins=30, density=True, alpha=0.8, label='NPE posteriors')
    plt.plot(x_vals, pdf_theoretical, 'r', lw=1, label=r'Theoretical scaled $\chi^2_2$')
    plt.legend()
    plt.xlabel("D_KL")
    plt.ylabel("density")
    plt.title("Null calibration of D_KL (data realisations under null)")
    plt.show()

    plt.figure(figsize=(6, 3))
    plt.hist(dkls_perturbed, bins=30, density=True)
    plt.xlabel("D_KL")
    plt.ylabel("density")
    plt.title("Perturbed calibration of D_KL (systematic injected into split 2)")
    plt.show()

    print("Null 95 percent critical value:", crit_val_95)
    print("Perturbed 95 percent critical value:", crit_val_95_perturbed)

    return dkls, crit_val_95, dkls_perturbed, crit_val_95_perturbed

# %%
dkls, crit_val_95, dkls_perturbed, crit_val_95_perturbed = calibrate_null_dkl_and_perturbed(
    posterior1_direct, posterior2_direct, prior,
    1000, 2000,
    loc1, scale1, loc1, scale1, delta_investigate,
)
# Out:
# 0/1000
# 100/1000
# 200/1000
# 300/1000
# 400/1000
# 500/1000
# 600/1000
# 700/1000
# 800/1000
# 900/1000
# Null 95 percent critical value: 5.554111886024462
# Perturbed 95 percent critical value: 7.334150862693786

# %% [markdown]
# ### Sensitivity sweep over $\epsilon$
#
# Adapted from the shift sweep in `Adapting Current Code.ipynb` (pipeline_methodology §13a).
# The systematic here is a constant off-diagonal correlation $\epsilon$ injected into split 2's
# likelihood covariance, $\Sigma_\text{lik} = \sigma^2 \mathbf{I} + \epsilon\,\sigma^2\,(\mathbf{1}\mathbf{1}^\top - \mathbf{I})$.
#
# We split the calibration so the null is computed **once at high $N$** and the perturbed
# distribution is computed cheaply per $\epsilon$:
#
# - **Null** ($N \sim 1\text{-}2k$): the 95th-percentile is a tail quantile, so its MC noise scales as $1/\sqrt{0.05 N}$.
# - **Perturbed** ($N \sim 200\text{-}500$): we only need the *median*, which uses the whole distribution and is well-behaved at low $N$.
#
# Posteriors are unchanged (still null-trained); the systematic only enters via the
# *observed* split, in line with James/Will's correction (methodology_discussion_notes.md).

# %%
# ---------------------------------------------------------------------------
# Null-once / perturbed-many helpers (parallel) -- eps sweep variant
#
# Adapted from Adapting Current Code.ipynb. The only change is in the
# perturbed worker: instead of shifting the mean by `loc1 + shift`, we
# inject an off-diagonal correlation `eps` into the split-2 likelihood
# via `noisy_correlated_simulator`.
# ---------------------------------------------------------------------------
from joblib import Parallel, delayed
from scipy.stats import chi2


def _null_only_iter(i, posterior1, posterior2, prior, n_theta, loc1, scale1):
    """Worker: one null D_KL sample. Both splits drawn from the null simulator."""
    torch.set_num_threads(1)
    theta_i = prior.sample((1,)).squeeze(0)
    x1_i    = simulator(theta_i, loc1, scale1)
    x2_i    = simulator(theta_i, loc1, scale1)
    dkl, _, _ = calc_dkl(posterior1, posterior2, x1_i, x2_i, n_theta=n_theta)
    return dkl


def calibrate_null_dkl_only_parallel(posterior1, posterior2, prior, N, n_theta,
                                     loc1, scale1, n_jobs=24, dkl_obs=None):
    """Null D_KL distribution -- run ONCE before any eps sweep.
    Returns (dkls, crit_val_95).
    """
    dkls = np.array(Parallel(n_jobs=n_jobs)(
        delayed(_null_only_iter)(i, posterior1, posterior2, prior, n_theta, loc1, scale1)
        for i in range(N)
    ))
    crit_val_95 = float(np.quantile(dkls, 0.95))

    # analytic null D_KL ~ scaled chi^2_2 for an isotropic 2D Gaussian
    s = float(scale1)
    c = 2.0 / (s + 2.0)
    x_max  = max(float(np.max(dkls)), 15.0)
    x_vals = np.linspace(0.01, x_max, 200)
    pdf_theoretical = (1.0 / c) * chi2.pdf(x_vals / c, df=2)

    plt.figure(figsize=(8, 4.5), dpi=150)
    plt.gca().set_axisbelow(True)
    plt.grid(axis="y", linestyle="--", alpha=0.7)
    plt.grid(axis="x", linestyle=":",  alpha=0.4)
    plt.hist(dkls, bins=60, density=True, color="tab:blue",
             label="NPE Posteriors (Null)")
    plt.plot(x_vals, pdf_theoretical, color="purple", linewidth=2.5,
             label=r"Theoretical Scaled $\chi^2_2$")
    if dkl_obs is not None:
        plt.axvline(dkl_obs, color="black", linestyle="dashed", linewidth=2.5,
                    label=fr"Observed $D_{{KL}}$ ({dkl_obs:.2f})")
    plt.axvline(crit_val_95, color="red", linestyle="dashed", linewidth=2.5,
                label=fr"95% Critical Value ({crit_val_95:.3f})")
    plt.xlabel(r"Kullback-Leibler Divergence ($D_{KL}$)", fontsize=14, labelpad=10)
    plt.ylabel("Probability Density", fontsize=14, labelpad=10)
    plt.title(r"Null Calibration of $D_{KL}$ (2D Gaussian)", fontsize=16, pad=15)
    plt.xticks(fontsize=12); plt.yticks(fontsize=12)
    plt.legend(fontsize=12, frameon=True, shadow=True,
               facecolor="white", edgecolor="black", borderpad=0.8)
    plt.tight_layout(); plt.show()
    print(f"Null 95% critical value: {crit_val_95:.4f}  (N={N})")
    return dkls, crit_val_95


def _perturb_only_iter_delta(i, posterior1, posterior2, prior, n_theta,
                           loc1, scale1, delta):
    """Worker: one perturbed D_KL sample.

    x1: null simulator. x2: noisy_correlated_simulator with off-diag eps.
    Same theta_i and same null/correlated split structure as the observed pair.
    """
    torch.set_num_threads(1)
    theta_i = prior.sample((1,)).squeeze(0)
    x1_i    = simulator(theta_i, loc1, scale1)
    x2_i_p  = noisy_scaled_cov_simulator(theta_i, loc1, scale1, delta)
    dkl, _, _ = calc_dkl(posterior1, posterior2, x1_i, x2_i_p, n_theta=n_theta)
    return dkl


def calibrate_perturb_dkl_only_parallel_delta(posterior1, posterior2, prior, N, n_theta,
                                            loc1, scale1, delta, crit_val_95,
                                            n_jobs=24, plot=True):
    """Perturbed D_KL distribution at one eps. N=200-500 is sufficient for the median.
    Returns (dkls_p, median_p).
    """
    dkls_p = np.array(Parallel(n_jobs=n_jobs)(
        delayed(_perturb_only_iter_delta)(
            i, posterior1, posterior2, prior, n_theta, loc1, scale1, delta
        )
        for i in range(N)
    ))
    median_p = float(np.median(dkls_p))

    if plot:
        plt.figure(figsize=(8, 4.5), dpi=150)
        plt.gca().set_axisbelow(True)
        plt.grid(axis="y", linestyle="--", alpha=0.7)
        plt.grid(axis="x", linestyle=":",  alpha=0.4)
        plt.hist(dkls_p, bins=40, density=True, color="tab:orange",
                 label=fr"NPE Posteriors ($\delta$={delta:.4f})")
        plt.axvline(median_p, color="black", linestyle="dashed", linewidth=2.5,
                    label=f"Median Perturbed ({median_p:.3f})")
        plt.axvline(crit_val_95, color="red", linestyle="dashed", linewidth=2.5,
                    label=f"95% Null Threshold ({crit_val_95:.3f})")
        plt.xlabel(r"Kullback-Leibler Divergence ($D_{KL}$)", fontsize=14, labelpad=10)
        plt.ylabel("Probability Density", fontsize=14, labelpad=10)
        plt.title(rf"Perturbed $D_{{KL}}$ -- $\delta$ = {delta:.4f}", fontsize=16, pad=15)
        plt.xticks(fontsize=12); plt.yticks(fontsize=12)
        plt.legend(fontsize=12, frameon=True, shadow=True,
                   facecolor="white", edgecolor="black", borderpad=0.8)
        plt.tight_layout(); plt.show()

    return dkls_p, median_p

# %%
# ---------------------------------------------------------------------------
# Sensitivity sweep: null ONCE at high N, perturbed cheaply per eps
# ---------------------------------------------------------------------------

N_null        = 10000  # high N -- 95th-percentile stability
   # lower N is fine for the median
n_theta_sweep = 1000

# Step 1 -- null distribution, computed once
dkls_null_sweep, crit_val_95_sweep = calibrate_null_dkl_only_parallel(
    posterior1_direct, posterior2_direct, prior,
    N=N_null, n_theta=n_theta_sweep,
    loc1=loc1, scale1=scale1,
    n_jobs=24, dkl_obs=dkl_obs,
)
# Out:
# /data/vault/jv447/venvs/research-project/lib/python3.11/site-packages/nflows/transforms/lu.py:80: UserWarning: torch.triangular_solve is deprecated in favor of torch.linalg.solve_triangularand will be removed in a future PyTorch release.
# torch.linalg.solve_triangular has its arguments reversed and does not return a copy of one of the inputs.
# X = torch.triangular_solve(B, A).solution
# should be replaced with
# X = torch.linalg.solve_triangular(A, B). (Triggered internally at ../aten/src/ATen/native/BatchLinearAlgebra.cpp:2190.)
#   outputs, _ = torch.triangular_solve(
# /data/vault/jv447/venvs/research-project/lib/python3.11/site-packages/nflows/transforms/lu.py:80: UserWarning: torch.triangular_solve is deprecated in favor of torch.linalg.solve_triangularand will be removed in a future PyTorch release.
# torch.linalg.solve_triangular has its arguments reversed and does not return a copy of one of the inputs.
# X = torch.triangular_solve(B, A).solution
# should be replaced with
# ...

# %%
N_pert        = 10000 

# Step 2 -- sweep eps; stop once sensitivity threshold (median > 95% null) is reached.
#   Start coarse to bracket the threshold, then refine.
delta_to_test = np.array([6.55,6.6,6.65,6.7,6.75])
sweep_results = []   # (delta, median_p, detected)

print(f"\n{'delta':>8}  {'Median DKL':>12}  {'95% Null':>10}  {'Detected':>10}")
print("-" * 50)

first_detected = None
for delta_val in delta_to_test:
    dkls_p, median_p = calibrate_perturb_dkl_only_parallel_delta(
        posterior1_direct, posterior2_direct, prior,
        N=N_pert, n_theta=n_theta_sweep,
        loc1=loc1, scale1=scale1,
        delta=float(delta_val), # FIX: Keyword is now delta!
        crit_val_95=crit_val_95_sweep,
        n_jobs=24, plot=True,
    )
    detected = median_p >= crit_val_95_sweep
    sweep_results.append((float(delta_val), median_p, detected))
    print(f"{delta_val:>8.4f}  {median_p:>12.4f}  {crit_val_95_sweep:>10.4f}  {str(detected):>10}")
    if detected and first_detected is None:
        first_detected = float(delta_val)
        print(f"\n>>> Sensitivity threshold reached at delta = {first_detected:.4f} <<<\n")

# Step 3 -- summary plot: median perturbed DKL vs delta
delta_arr   = np.array([r[0] for r in sweep_results])
medians_arr = np.array([r[1] for r in sweep_results])

plt.figure(figsize=(8, 4.5), dpi=150)
plt.gca().set_axisbelow(True)
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.grid(axis="x", linestyle=":",  alpha=0.4)
plt.plot(delta_arr, medians_arr, "o-", color="tab:blue", linewidth=2,
         markersize=7, label=r"Median perturbed $D_{KL}$")
plt.axhline(crit_val_95_sweep, color="red", linestyle="dashed", linewidth=2.5,
            label=f"95% Null Threshold ({crit_val_95_sweep:.3f})")
if first_detected is not None:
    plt.axvline(first_detected, color="green", linestyle="dotted", linewidth=2,
                label=fr"First detection at $\delta$={first_detected:.4f}")
plt.xlabel(r"Variance Scaling $\delta$", fontsize=14, labelpad=10) # FIX: Axis Label
plt.ylabel(r"Median $D_{KL}$", fontsize=14, labelpad=10)
plt.title(r"Sensitivity Sweep: Median Perturbed $D_{KL}$ vs $\delta$",
          fontsize=16, pad=15)
plt.xticks(fontsize=12); plt.yticks(fontsize=12)
plt.legend(fontsize=12, frameon=True, shadow=True,
           facecolor="white", edgecolor="black", borderpad=0.8)
plt.tight_layout(); plt.show()
# Out:
#    delta    Median DKL    95% Null    Detected
# --------------------------------------------------
# /data/vault/jv447/venvs/research-project/lib/python3.11/site-packages/nflows/transforms/lu.py:80: UserWarning: torch.triangular_solve is deprecated in favor of torch.linalg.solve_triangularand will be removed in a future PyTorch release.
# torch.linalg.solve_triangular has its arguments reversed and does not return a copy of one of the inputs.
# X = torch.triangular_solve(B, A).solution
# should be replaced with
# X = torch.linalg.solve_triangular(A, B). (Triggered internally at ../aten/src/ATen/native/BatchLinearAlgebra.cpp:2190.)
#   outputs, _ = torch.triangular_solve(
# /data/vault/jv447/venvs/research-project/lib/python3.11/site-packages/nflows/transforms/lu.py:80: UserWarning: torch.triangular_solve is deprecated in favor of torch.linalg.solve_triangularand will be removed in a future PyTorch release.
# ...
